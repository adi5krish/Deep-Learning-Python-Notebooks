# %%
import os
import numpy as np
import tensorflow as tf
from scipy.io import loadmat,savemat

feature_dimension = 36
frames = 100
fc_neurons = 256
tf.set_random_seed(3456)

# %%
x = tf.placeholder(shape = [None, feature_dimension, frames], dtype = tf.float32) #inputs
print(x.shape)
y = tf.placeholder(shape = [None, 2], dtype = tf.float32) #labels
# Out:
# (?, 36, 100)

# %%
#conv layer 1
weights_conv1 = tf.get_variable("conv1_weights",
                                shape = [3,3,1,256],  
                                dtype = tf.float32,
                               initializer = tf.contrib.layers.xavier_initializer())
bias_conv1 = tf.get_variable("conv1_bias",
                             shape = [256],
                              dtype = tf.float32,
                              initializer = tf.contrib.layers.xavier_initializer())

#reshaping of input(batch_size, feature_width, feature_height,input_channels)
input_x = tf.reshape(x,[-1,feature_dimension, frames,1])
print(input_x)

conv1 = tf.nn.conv2d(input_x, weights_conv1, strides = [1,1,1,1], padding = 'VALID')
conv1_out = tf.nn.relu(conv1)
print(conv1_out)
# Out:
# Tensor("Reshape:0", shape=(?, 60, 100, 1), dtype=float32)
# Tensor("Relu:0", shape=(?, 29, 49, 256), dtype=float32)

# %%
# conv layer 2
weights_conv2 = tf.get_variable("conv2_weights",
                               shape = [3,3,256,128],
                               dtype = tf.float32,
                                initializer = tf.contrib.layers.xavier_initializer())
bias_conv2 = tf.get_variable("conv2_bias",
                             shape = [128],
                            dtype = tf.float32,
                            initializer = tf.contrib.layers.xavier_initializer())

conv2 = tf.nn.conv2d(conv1_out,weights_conv2, strides = [1,2,2,1], padding = 'VALID')
conv2_out = tf.nn.relu(conv2)
print(conv2_out)
# Out:
# Tensor("Relu_1:0", shape=(?, 14, 24, 128), dtype=float32)

# %%
# conv layer 3
weights_conv3 = tf.get_variable("conv3_weights",
                               shape = [5,5,128,128],
                               dtype = tf.float32,
                                initializer = tf.contrib.layers.xavier_initializer())
bias_conv3 = tf.get_variable("conv3_bias",
                             shape = [128],
                            dtype = tf.float32,
                            initializer = tf.contrib.layers.xavier_initializer())

conv3 = tf.nn.conv2d(conv2_out,weights_conv3, strides = [1,2,2,1], padding = 'VALID')
conv3_out = tf.nn.relu(conv3)

# %%
#max pool1
pool1_out = tf.layers.max_pooling2d(conv3_out,pool_size = [4,4], strides = [1,1], padding = 'VALID')
print(pool1_out)
# Out:
# Tensor("max_pooling2d/MaxPool:0", shape=(?, 2, 7, 128), dtype=float32)

# %%
#unstacking the input
reshape_input = tf.reshape(conv3_out,[-1,int(conv3_out.shape[1])*int(conv3_out.shape[2]),int(conv3_out.shape[3])])
input_lstm = tf.unstack(reshape_input,reshape_input.shape[2],2)
#print(input_lstm)

# %%
lstm_fw1 = tf.contrib.rnn.LSTMCell( 64, use_peepholes = True,
                    initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=3456, dtype=tf.float32))
lstm_fw2 = tf.contrib.rnn.LSTMCell( 64, use_peepholes = True,
                    initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=3457, dtype=tf.float32))

lstm_fw = tf.contrib.rnn.MultiRNNCell((lstm_fw1, lstm_fw2))


lstm_back1 = tf.contrib.rnn.LSTMCell( 64, use_peepholes = True,
                    initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=3458, dtype=tf.float32))
lstm_back2 = tf.contrib.rnn.LSTMCell( 64, use_peepholes = True,
                    initializer = tf.contrib.layers.xavier_initializer(uniform=True, seed=3459, dtype=tf.float32))

lstm_back = tf.contrib.rnn.MultiRNNCell((lstm_back1, lstm_back2))

blstm_out, state_fw, state_bw = tf.contrib.rnn.stack_bidirectional_rnn( [lstm_fw], [lstm_back], input_lstm, dtype = tf.float32)

# %%
#print(blstm_out[-1])
#dense layer 1

dense_1 = 512
dense_1_weights = tf.get_variable( "dense_1_weights",
                                  shape = [ 128, dense_1],
                                  dtype = tf.float32,
                                  initializer = tf.contrib.layers.xavier_initializer())

dense_1_bias = tf.get_variable( "dense_1_bias",
                                    shape = [dense_1],
                                    dtype = tf.float32,
                                   initializer = tf.contrib.layers.xavier_initializer())

dense_1_dnn = tf.matmul( blstm_out[-1],dense_1_weights) + dense_1_bias
dense_1_out = tf.nn.relu(dense_1_dnn)
print(dense_1_out)
# Out:
# Tensor("Relu_3:0", shape=(?, 512), dtype=float32)

# %%
#dense layer 2

dense_2 = 512
dense_2_weights = tf.get_variable( "dense_2_weights",
                                  shape = [ dense_1, dense_2],
                                  dtype = tf.float32,
                                  initializer = tf.contrib.layers.xavier_initializer())

dense_2_bias = tf.get_variable( "dense_2_bias",
                                    shape = [dense_2],
                                    dtype = tf.float32,
                                   initializer = tf.contrib.layers.xavier_initializer())

dense_2_dnn = tf.matmul(dense_1_out,dense_2_weights) + dense_2_bias
dense_2_out = tf.nn.relu(dense_2_dnn)
print(dense_2_out)
# Out:
# Tensor("Relu_4:0", shape=(?, 512), dtype=float32)

# %%
dense_3 = 256
dense_3_weights = tf.get_variable("dense_3_weights",
                                 shape = [dense_2,dense_3],
                                 dtype = tf.float32,
                                 initializer = tf.contrib.layers.xavier_initializer())
dense_3_bias = tf.get_variable( "dense_3_bias",
                                    shape = [dense_3],
                                    dtype = tf.float32,
                                   initializer = tf.contrib.layers.xavier_initializer())

dense_3_dnn = tf.matmul(dense_2_out,dense_3_weights) + dense_3_bias
dense_3_out = tf.nn.relu(dense_3_dnn)
print(dense_3_out)
# Out:
# Tensor("Relu_5:0", shape=(?, 256), dtype=float32)

# %%
#output layer

final = 2
final_weights = tf.get_variable( "final_weights",
                                  shape = [ dense_3, final],
                                  dtype = tf.float32,
                                  initializer = tf.contrib.layers.xavier_initializer())

final_bias = tf.get_variable( "final_bias",
                                    shape = [final],
                                    dtype = tf.float32,
                                   initializer = tf.contrib.layers.xavier_initializer())

final_dnn = tf.matmul( dense_3_out, final_weights) + final_bias
final_out = tf.nn.softmax(final_dnn)
print(final_out)
# Out:
# Tensor("Softmax:0", shape=(?, 2), dtype=float32)

# %%
# losses and optimizers

cross_entropy = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits(labels = y, logits = final_dnn))
optimizer = tf.train.AdamOptimizer(1e-4)
train_step = optimizer.minimize(cross_entropy)

#correct_predictions = tf.equal( tf.argmax(final_dnn, 1), tf.argmax(output_y, 1))
#accuracy = tf.reduce_mean( tf.cast( correct_predictions, tf.float32 ))

# %%
#initializing tensors using sessoion
session = tf.InteractiveSession()

init = tf.global_variables_initializer()
saver = tf.train.Saver(max_to_keep=None)

features_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\overlapData'
development_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\devoverlapData'
eval_features_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\evaloverlapData'
model_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\Models_60D_CNNRNN_3c_1p_2lstm_3d'

dev_sp_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\Dev_sp_60D_CNNRNN_3c_1p_2lstm_3d'
eval_sp_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\Eval_sp_60D_CNNRNN_3c_1p_2lstm_3d'

# %%
def cal_eer(scores_true, scores_false):
    
    """ Calculate EER
        Args:
            scores_true: A score list of positive samples
            scores_false: A score list of negative samples
        Return:
            (EER, threshold)
        Note:
            Here, the threshold is set, and if the score is higher than or equal to the threshold,
            the decision is passed, and the decision is rejected as below.
    """
    min1 = min(scores_true)
    min2 = min(scores_false)
    low = min(min1, min2)
    max1 = max(scores_true)
    max2 = max(scores_false)
    high = max(max1, max2)
    FAR = -55
    FRR = -55
    mid = -100
    # Bisection find threshold
    while True:
        bef_FAR = FAR 
        bef_FRR = FRR
        bef_mid = mid
        mid = (high + low) / 2
        FRR = sum([1 for s in scores_true if s < mid]) / len(scores_true)
        FAR = sum([1 for s in scores_false if s >= mid]) / len(scores_false)
        #print("FRR  ",FRR," FAR   ",FAR,"   mid   ",mid)

        if abs(FRR - FAR) < 1e-7:
            print("FRR  ",FRR," FAR   ",FAR,"   mid   ",mid)
            break

        if FRR < FAR:
            low = mid
        else:
            high = mid
            
        if bef_FAR == FAR :
            if bef_FRR == FRR :
                if bef_mid == mid :
                    print("FRR  ",FRR," FAR   ",FAR,"   mid   ",mid)
                    break

    EER  =  FRR
    return EER, (high + low) / 2

# %%
from scipy.io import savemat

def get_EER(test_path, index, sp_path ):
    scores = []
    development_labels = []
    probabilities = []

    #test_path = "C:\\Users\\project1\\Desktop\\Siva\\HT_IFCC_hemlata\\CNN_input_testing_dev"
    indexs = (len(list(os.listdir(test_path))))//2
    
    for folders in range(1, indexs+1):
        features = np.load(os.path.join(test_path, "features_"+str(folders)+".npy"))
        labels = np.load(os.path.join(test_path, "labels_"+str(folders)+".npy"))
        patches = labels.shape[0]
        patch_prob = session.run(final_out, feed_dict = {x:features})
        final_prob = np.zeros([2])
        
        for i in range(patches):
            if(patch_prob[i][0] == 0):
                patch_prob[i][0] = 1e-25
            if(patch_prob[i][1] == 0):
                patch_prob[i][1] = 1e-25
                
            final_prob[0] = final_prob[0] + np.log(patch_prob[i][0])
            final_prob[1] = final_prob[1] + np.log(patch_prob[i][1])

        final_prob = final_prob / patches
        score = (final_prob[0]) - (final_prob[1])
        audio_label = labels[0]

        scores.append(score)
        probabilities.append( np.mean(patch_prob, axis=0) )
        development_labels.append( audio_label )

    scores = np.array(scores)
    development_labels = np.array(development_labels)
    probabilities = np.array(probabilities)

    scores_genuine = []
    scores_spoof = []
    prob_genuine = []
    prob_spoof = []

    for i in range(development_labels.shape[0]):
        if development_labels[i][0] == 1 :
            scores_genuine.append(scores[i])
            prob_genuine.append(probabilities[i])
            
        elif development_labels[i][1] == 1:
            scores_spoof.append(scores[i])
            prob_spoof.append(probabilities[i])

    scores_genuine = np.array(scores_genuine)
    scores_spoof = np.array(scores_spoof)
    
    prob_genuine = np.array(prob_genuine)
    prob_spoof = np.array(prob_spoof)
    
    #print(scores_genuine.shape,scores_spoof.shape)
    
    a,b = cal_eer(scores_genuine, scores_spoof)
    
    score_path = os.path.join(sp_path, "scores")
    prob_path = os.path.join(sp_path, "probabilities")
    
    if not os.path.exists(score_path):
        os.makedirs(score_path)
        
    if not os.path.exists(prob_path):
        os.makedirs(prob_path)
        
    prob_file = "probabilities_"+str(index)
    sc_file = "scores_"+str(index)
    savemat(os.path.join(score_path, sc_file), { 'genuine':scores_genuine, 'spoof':scores_spoof, 'eer' : a*100 })
    savemat(os.path.join(prob_path, prob_file), { 'genuine':prob_genuine, 'spoof':prob_spoof })
    
    return a

# %%
#Training and testing accuracy
session.run(init)

if not os.path.exists(model_path):
    os.makedirs(model_path)
    
if not os.path.exists(dev_sp_path):
    os.makedirs(dev_sp_path)
    
batches = (len(list(os.listdir(features_path))))//2
    
for i in range(0,50):
    for j in range(1,batches+1):  #number of batches
        filename = "batch_"+str(j)+".npy"
        labelsname= "label_"+str(j)+".npy"
        
        features = np.load(os.path.join(features_path, filename))
        labels = np.load(os.path.join(features_path, labelsname))

        train_step.run(session = session,feed_dict={ x:features, y:labels })
        
    save_path = saver.save(session, os.path.join(model_path,"Model"+str(i+1)))
    
    print("iteration  ",(i+1))
    eer_dev = get_EER(development_path, (i+1), dev_sp_path)
    print(" develop eer  ",eer_dev)
    print()
# Out:
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model1 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   1
# FRR   0.22894736842105262  FAR    0.2294736842105263    mid    1.02137106508
#  develop eer   0.22894736842105262
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model2 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   2
# FRR   0.16842105263157894  FAR    0.16842105263157894    mid    1.65744674633
#  develop eer   0.16842105263157894
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model3 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   3
# FRR   0.15263157894736842  FAR    0.15157894736842106    mid    1.47487166247
#  develop eer   0.15263157894736842
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model4 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   4
# FRR   0.14210526315789473  FAR    0.1431578947368421    mid    1.19873034948
#  develop eer   0.14210526315789473
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model5 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   5
# FRR   0.1368421052631579  FAR    0.1368421052631579    mid    1.05006892216
#  develop eer   0.1368421052631579
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model6 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   6
# FRR   0.1355263157894737  FAR    0.13473684210526315    mid    0.938149004217
#  develop eer   0.1355263157894737
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model7 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   7
# FRR   0.1355263157894737  FAR    0.13473684210526315    mid    0.912223152816
#  develop eer   0.1355263157894737
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model8 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   8
# FRR   0.13421052631578947  FAR    0.1336842105263158    mid    0.922463666958
#  develop eer   0.13421052631578947
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model9 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   9
# FRR   0.13157894736842105  FAR    0.13052631578947368    mid    0.766615894047
#  develop eer   0.13157894736842105
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model10 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   10
# FRR   0.13026315789473683  FAR    0.13052631578947368    mid    0.732818812807
#  develop eer   0.13026315789473683
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model11 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   11
# FRR   0.12894736842105264  FAR    0.12947368421052632    mid    0.723748000339
#  develop eer   0.12894736842105264
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model12 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   12
# FRR   0.12894736842105264  FAR    0.12842105263157894    mid    1.28694460564
#  develop eer   0.12894736842105264
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model13 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   13
# FRR   0.12368421052631579  FAR    0.1231578947368421    mid    2.71329510159
#  develop eer   0.12368421052631579
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model14 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   14
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    3.81839482661
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model15 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   15
# FRR   0.13157894736842105  FAR    0.13263157894736843    mid    4.9100763301
#  develop eer   0.13157894736842105
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model16 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   16
# FRR   0.14210526315789473  FAR    0.14105263157894737    mid    4.00790657188
#  develop eer   0.14210526315789473
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model17 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   17
# FRR   0.1355263157894737  FAR    0.13578947368421052    mid    3.48445594081
#  develop eer   0.1355263157894737
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model18 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   18
# FRR   0.13157894736842105  FAR    0.13157894736842105    mid    3.54065124859
#  develop eer   0.13157894736842105
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model19 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   19
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    3.73729246595
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model20 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   20
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    2.32880217736
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model21 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   21
# FRR   0.12105263157894737  FAR    0.12210526315789473    mid    3.0420538997
#  develop eer   0.12105263157894737
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model22 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   22
# FRR   0.125  FAR    0.12526315789473685    mid    1.79407192245
#  develop eer   0.125
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model23 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   23
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    2.0098918003
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model24 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   24
# FRR   0.12763157894736843  FAR    0.12842105263157894    mid    0.557820437775
#  develop eer   0.12763157894736843
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model25 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   25
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    1.35215549212
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model26 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   26
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    0.860259326718
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model27 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   27
# FRR   0.12763157894736843  FAR    0.12842105263157894    mid    0.225146100263
#  develop eer   0.12763157894736843
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model28 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   28
# FRR   0.12763157894736843  FAR    0.12842105263157894    mid    0.862202889063
#  develop eer   0.12763157894736843
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model29 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   29
# FRR   0.11973684210526316  FAR    0.12    mid    0.60560250141
#  develop eer   0.11973684210526316
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model30 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   30
# FRR   0.125  FAR    0.12526315789473685    mid    0.343412239895
#  develop eer   0.125
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model31 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   31
# FRR   0.12236842105263158  FAR    0.1231578947368421    mid    0.662171859841
#  develop eer   0.12236842105263158
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model32 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   32
# FRR   0.12368421052631579  FAR    0.12421052631578948    mid    0.0244669060085
#  develop eer   0.12368421052631579
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model33 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   33
# FRR   0.12894736842105264  FAR    0.12947368421052632    mid    0.2645744526
#  develop eer   0.12894736842105264
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model34 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   34
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    0.73062119141
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model35 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   35
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    2.7190062024
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model36 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   36
# FRR   0.12763157894736843  FAR    0.12736842105263158    mid    2.0418805798
#  develop eer   0.12763157894736843
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model37 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   37
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    3.76169868598
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model38 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   38
# FRR   0.125  FAR    0.12526315789473685    mid    0.576667242479
#  develop eer   0.125
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model39 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   39
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    1.7163189677
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model40 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   40
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    1.17785306364
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model41 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   41
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    5.23085758391
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model42 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   42
# FRR   0.13026315789473683  FAR    0.13052631578947368    mid    0.777279944604
#  develop eer   0.13026315789473683
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model43 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   43
# FRR   0.12368421052631579  FAR    0.1231578947368421    mid    14.6548561576
#  develop eer   0.12368421052631579
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model44 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   44
# FRR   0.12105263157894737  FAR    0.12105263157894737    mid    3.26658182997
#  develop eer   0.12105263157894737
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model45 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   45
# FRR   0.12236842105263158  FAR    0.12210526315789473    mid    4.62148938395
#  develop eer   0.12236842105263158
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model46 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   46
# FRR   0.12105263157894737  FAR    0.12105263157894737    mid    11.4711471635
#  develop eer   0.12105263157894737
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model47 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   47
# FRR   0.12631578947368421  FAR    0.12631578947368421    mid    2.49810713459
#  develop eer   0.12631578947368421
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model48 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   48
# FRR   0.12368421052631579  FAR    0.1231578947368421    mid    14.8783240484
#  develop eer   0.12368421052631579
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model49 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   49
# FRR   0.12236842105263158  FAR    0.12210526315789473    mid    2.18411981443
#  develop eer   0.12236842105263158
#
# INFO:tensorflow:C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model50 is not in all_model_checkpoint_paths. Manually adding it.
# iteration   50
# FRR   0.12368421052631579  FAR    0.12421052631578948    mid    5.15575182588
#  develop eer   0.12368421052631579

# %%
eval_features_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\evaloverlapData'
eval_sp_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\Eval_sp_60D_CNNRNN_3c_1p_2lstm_3d'

if not os.path.exists(eval_sp_path):
    os.makedirs(eval_sp_path)
    
with tf.Session() as session:
    for i in range(35,50):
        saver.restore(session,os.path.join(model_path,"Model"+str(i+1)))
        print("iteration  ", (i+1))
        eval_eer = get_EER(eval_features_path, (i+1), eval_sp_path)
        print("eval eer  ", eval_eer)
        print()
# Out:
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model36
# iteration   36
# FRR   0.1926040061633282  FAR    0.19337108594270486    mid    6.5584796362
# eval eer   0.1926040061633282
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model37
# iteration   37
# FRR   0.19106317411402157  FAR    0.1911225849433711    mid    11.8590426777
# eval eer   0.19106317411402157
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model38
# iteration   38
# FRR   0.19029275808936827  FAR    0.1902898067954697    mid    5.06259353814
# eval eer   0.19029275808936827
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model39
# iteration   39
# FRR   0.19722650231124808  FAR    0.19711858760826115    mid    5.22788413564
# eval eer   0.19722650231124808
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model40
# iteration   40
# FRR   0.19568567026194145  FAR    0.1963690872751499    mid    4.29606725558
# eval eer   0.19568567026194145
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model41
# iteration   41
# FRR   0.20107858243451462  FAR    0.20044970019986674    mid    17.3209611995
# eval eer   0.20107858243451462
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model42
# iteration   42
# FRR   0.19491525423728814  FAR    0.19487008660892738    mid    2.65629799912
# eval eer   0.19491525423728814
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model43
# iteration   43
# FRR   0.19029275808936827  FAR    0.1902898067954697    mid    32.999118328
# eval eer   0.19029275808936827
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model44
# iteration   44
# FRR   0.1933744221879815  FAR    0.19370419720186544    mid    9.50602262628
# eval eer   0.1933744221879815
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model45
# iteration   45
# FRR   0.18875192604006163  FAR    0.18870752831445703    mid    12.3122353404
# eval eer   0.18875192604006163
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model46
# iteration   46
# FRR   0.19645608628659475  FAR    0.1965356429047302    mid    24.060160485
# eval eer   0.19645608628659475
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model47
# iteration   47
# FRR   0.1941448382126348  FAR    0.1936209193870753    mid    8.62649143397
# eval eer   0.1941448382126348
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model48
# iteration   48
# FRR   0.1941448382126348  FAR    0.19437041972018654    mid    34.5719957006
# eval eer   0.1941448382126348
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model49
# iteration   49
# FRR   0.1941448382126348  FAR    0.19445369753497668    mid    8.22623504936
# eval eer   0.1941448382126348
#
# INFO:tensorflow:Restoring parameters from C:\Users\HIMANSHU\Desktop\Aditya\ASVspoof2017_CMPOC_CMVN\Models_60D_CNNRNN_3c_1p_2lstm_3d\Model50
# iteration   50
# FRR   0.1933744221879815  FAR    0.1932045303131246    mid    15.5877071424
# eval eer   0.1933744221879815

# %%
eval_features_path = 'C:\\Users\\HIMANSHU\\Desktop\\Aditya\\ASVspoof2017_CMPOC_CMVN\\evaloverlapData'
no_of_files = len(list(os.listdir(eval_features_path)))//2
for i in range(1298,1299):
    feature_name = 'features_'+str(i+1)+'.npy'
    matFile = np.load(os.path.join(eval_features_path,feature_name))
    print(matFile.shape)
#print(no_of_files)
# Out:
# (16, 90, 100)
